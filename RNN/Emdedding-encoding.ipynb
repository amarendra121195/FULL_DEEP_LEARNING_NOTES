# %%
import numpy as np
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
docs =["go india",
       "india india",
       "hip hip hooray",
       "jitega bhai jitega india india",
       "bharat mata ki jai",
       "kohali kohali",
       "sachin sachin",
       "dhoni dhoni",
       "modi ji ke jai",
       "inquilab zindabad"
]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer(oov_token="amarendra")
 # out of vocabulary token for unknown words, it means if any word is not present in the training data, it will be replaced by this token

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.index_word
# Out:
# {1: 'amarendra',
#  2: 'india',
#  3: 'hip',
#  4: 'jitega',
#  5: 'jai',
#  6: 'kohali',
#  7: 'sachin',
#  8: 'dhoni',
#  9: 'go',
#  10: 'hooray',
#  11: 'bhai',
#  12: 'bharat',
#  13: 'mata',
#  14: 'ki',
#  15: 'modi',
#  16: 'ji',
#  17: 'ke',
#  18: 'inquilab',
#  19: 'zindabad'}

# %%
tokenizer.word_counts
# Out:
# OrderedDict([('go', 1),
#              ('india', 5),
#              ('hip', 2),
#              ('hooray', 1),
#              ('jitega', 2),
#              ('bhai', 1),
#              ('bharat', 1),
#              ('mata', 1),
#              ('ki', 1),
#              ('jai', 2),
#              ('kohali', 2),
#              ('sachin', 2),
#              ('dhoni', 2),
#              ('modi', 1),
#              ('ji', 1),
#              ('ke', 1),
#              ('inquilab', 1),
#              ('zindabad', 1)])

# %%
tokenizer.document_count
# Out:
# 10

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 2],
#  [2, 2],
#  [3, 3, 10],
#  [4, 11, 4, 2, 2],
#  [12, 13, 14, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [15, 16, 17, 5],
#  [18, 19]]

# %%
# above the all sequences are integer encoded representation of the text data, now we will pad these sequences to make them of same length, using pad_sequences from keras.preprocessing.sequence
from keras.utils import pad_sequences

# %%
sequences = pad_sequences(sequences, padding='post')

# %%
sequences
# Out:
# array([[ 9,  2,  0,  0,  0],
#        [ 2,  2,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 4, 11,  4,  2,  2],
#        [12, 13, 14,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [15, 16, 17,  5,  0],
#        [18, 19,  0,  0,  0]], dtype=int32)

# %%
model = Sequential()
model.add(Embedding(17,output_dim=2, input_length=5)) # input_dim is the size of the vocabulary, output_dim is the size of the embedding vector, input_length is the length of the input sequences

model.summary()
# Out:
# c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','mse')

# %%
pred = model.predict(sequences)
