# %%
from keras import Sequential
from keras.layers import Dense, SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3,input_shape=(4,5)))
model.add(Dense(1,activation='sigmoid'))
model.summary()
# Out:
# c:\Users\Lenovo\anaconda3\envs\amar\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)  # Input weights
model.get_weights()[0] # Recurrent weights
# Out:
# (5, 3)
# array([[-0.18568474,  0.16202849, -0.5631125 ],
#        [ 0.2507742 ,  0.66136724,  0.05302113],
#        [-0.29887688,  0.1672191 ,  0.6531214 ],
#        [ 0.00567997, -0.45957178,  0.46503788],
#        [-0.40939528, -0.23708856, -0.3821976 ]], dtype=float32)

# %%
print(model.get_weights()[1].shape)  # Input weights
model.get_weights()[1] # Recurrent weights
# Out:
# (3, 3)
# array([[ 0.2543708 , -0.94691247, -0.1966018 ],
#        [-0.8009535 , -0.32020074,  0.5059101 ],
#        [ 0.5420046 , -0.02878013,  0.8398826 ]], dtype=float32)

# %%
print(model.get_weights()[2].shape)  # Input weights
model.get_weights()[2] # Recurrent weights
# Out:
# (3,)
# array([0., 0., 0.], dtype=float32)

# %%
print(model.get_weights()[3].shape)  # Input weights
model.get_weights()[3] # Recurrent weights
# Out:
# (3, 1)
# array([[ 0.37261438],
#        [-0.66821694],
#        [-0.91614497]], dtype=float32)

# %%
print(model.get_weights()[4].shape)  # Input weights
model.get_weights()[4] # Recurrent weights
# Out:
# (1,)
# array([0.], dtype=float32)
